# %%
print("HEllo")
# Out:
# HEllo

# %%
revenue = 100
expenses = 90

# %%
type(revenue)
print(type(expenses))
# Out:
# <class 'int'>

# %%
profit = revenue - expenses
print(profit)
# Out:
# 10

# %%
margin = profit * 100 / revenue
margin
# Out:
# 10.0

# %%
type(margin)
# Out:
# float

# %%
type(profit)
# Out:
# int

# %%
id(profit)
# Out:
# 140726012803800

# %%
expenses_descrip = "sadfnaksjdnfkasdf asdfjasndfkjasdf asdfasjdfnkasdfasd fasdfkjansdfkjanskd"

# %%
type(expenses_descrip)
# Out:
# str

# %%
expenses_description = 'aafsdfasd fa sdfasd fa sdf asdf asdfasdfasd'

# %%
type(expenses_description)
# Out:
# str

# %%
len(expenses_description)
# Out:
# 43

# %% [markdown]
# # List **got**

# %%
expenses = [10, 34, 40, 4563456, 5, 65, 65, 6]

# %%
type(expenses)
# Out:
# list

# %%
expenses[1::2]
# Out:
# [34, 4563456, 65, 6]

# %%
len(expenses)
# Out:
# 8

# %%
revenue = 100
for exp in expenses:
    revenue -= exp
    print(f"Remaining Total : {revenue}")
# Out:
# Remaining Total : 90
# Remaining Total : 56
# Remaining Total : 16
# Remaining Total : -4563440
# Remaining Total : -4563445
# Remaining Total : -4563510
# Remaining Total : -4563575
# Remaining Total : -4563581
